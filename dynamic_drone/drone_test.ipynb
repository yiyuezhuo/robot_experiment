# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dynamic_drone import *

# %%
import matplotlib.pyplot as plt

# %%
def simulation(omega_arr, dt = 1/30, show=True, callback=None):
    '''
    omega_arr: length x 4 matrix
    '''
    
    length = omega_arr.shape[0]
    xyz_arr = np.zeros([length, 3])
    rpy_arr = np.zeros([length, 3])
    v_xyz_arr = np.zeros([length, 3])
    v_rpy_arr = np.zeros([length, 3])
    a_xyz_arr = np.zeros([length, 3])
    a_rpy_arr = np.zeros([length, 3])
    
    #dt=1/30
    
    for i in range(length):
        #omega = np.array([1.0, 1.0, 1.0, 1.0]) * 2
        omega = omega_arr[i]
        a_xyz, a_rpy = drone.step(omega, dt)
        
        xyz_arr[i,:] = drone.xyz
        rpy_arr[i,:] = drone.rpy
        v_xyz_arr[i,:] = drone.v_xyz
        v_rpy_arr[i,:] = drone.v_rpy
        a_xyz_arr[i,:] = a_xyz
        a_rpy_arr[i,:] = a_rpy
        
        if callback:
            callback(drone.xyz, drone.rpy, drone.v_xyz, drone.v_rpy, a_xyz, a_rpy)
    
    
    name_list = ['X','Y','Z',
                 'r','p','y',
                 "v_X","v_Y","v_Z",
                 "v_r","v_p","v_y",
                 'a_X','a_Y','a_Z',
                 'a_r','a_p','a_y']
    arr_list = [xyz_arr[:,0], xyz_arr[:,1], xyz_arr[:,2],
                rpy_arr[:,0], rpy_arr[:,1], rpy_arr[:,2],
                v_xyz_arr[:,0], v_xyz_arr[:,1], v_xyz_arr[:,2],
                v_rpy_arr[:,0], v_rpy_arr[:,1], v_rpy_arr[:,2],
                a_xyz_arr[:,0], a_xyz_arr[:,1], a_xyz_arr[:,2],
                a_rpy_arr[:,0], a_rpy_arr[:,1], a_rpy_arr[:,2]]
    
    
    for name, arr in zip(name_list, arr_list):
        if isinstance(show, (list, tuple, set)) or not show:
            if name not in show:
                continue
        plt.plot(arr)
        plt.title(name)
        plt.show()
            
    return {'name_list': name_list,
            'arr_list': arr_list,
            'xyz_arr': xyz_arr,
            'rpy_arr': rpy_arr,
            'v_xyz_arr': v_xyz_arr,
            'v_rpy_arr': v_rpy_arr,
            'a_xyz_arr': a_xyz_arr,
            'a_rpy_arr': a_rpy_arr}

# %%
xyz = np.array([0.0, 0.0, 0.0])
rpy = np.array([0.0, 0.0, 0.0])
drone = Drone(xyz, rpy, v_xyz=(0,0,0), v_rpy=(0,0,0), 
                 I=(1,1,1), m=1, b=1, l=1, d=1)

# %%
omega_arr = np.ones([1000, 4]) * 2
res = simulation(omega_arr)

# %%
xyz = np.array([0.0, 0.0, 0.0])
rpy = np.array([0.0, 0.0, 0.0])
drone = Drone(xyz, rpy, v_xyz=(0,0,0), v_rpy=(0,0,0), 
                 I=(1,1,1), m=1, b=1, l=1, d=1)

omega_arr = np.ones([1000, 4]) * 2
res = simulation(omega_arr, show=['Z','v_Z','a_Z'])

# %%
xyz = np.array([0.0, 0.0, 0.0])
rpy = np.array([0.0, 0.0, 0.0])
drone = Drone(xyz, rpy, v_xyz=(0,0,0), v_rpy=(0,0,0), 
                 I=(1,1,1), m=1, b=1, l=1, d=1)

omega_arr = np.ones([1000, 4])
omega_arr[:,1] = 2
omega_arr[:,2] = 2
res = simulation(omega_arr)

# %%
xyz = np.array([0.0, 0.0, 0.0])
rpy = np.array([0.0, 0.0, 0.0])
drone = Drone(xyz, rpy, v_xyz=(0,0,0), v_rpy=(0,0,0), 
                 I=(1,1,1), m=1, b=1, l=1, d=1)

omega_arr = np.ones([100, 4])
omega_arr[:5,1] = 2
omega_arr[:5,2] = 2
omega_arr[5:10,1] = 0
omega_arr[5:10,2] = 0
omega_arr
res = simulation(omega_arr)

# %%
xyz = np.array([0.0, 0.0, 0.0])
rpy = np.array([0.0, 0.0, 0.0])
drone = Drone(xyz, rpy, v_xyz=(0,0,0), v_rpy=(0,0,0), 
                 I=(1,1,1), m=1, b=1, l=1, d=1)

omega_arr = np.ones([100, 4])
omega_arr[:5,1] = 2
omega_arr[:5,2] = 2
omega_arr[5:20,1] = 0
omega_arr[5:20,2] = 0
omega_arr
res = simulation(omega_arr)

# %%
xyz = np.array([0.0, 0.0, 0.0])
rpy = np.array([0.0, 0.0, 0.0])
drone = Drone(xyz, rpy, v_xyz=(0,0,0), v_rpy=(0,0,0), 
                 I=(1,1,1), m=1, b=1, l=1, d=1)

omega_arr = np.ones([100, 4]) *2
omega_arr[:5,1] = 3
omega_arr[:5,2] = 3
omega_arr[5:13,1] = 1
omega_arr[5:13,2] = 1
omega_arr
res = simulation(omega_arr)

# %%
xyz = np.array([0.0, 0.0, 0.0])
rpy = np.array([0.0, 0.0, 0.0])
drone = Drone(xyz, rpy, v_xyz=(0,0,0), v_rpy=(0,0,0), 
                 I=(1,1,1), m=1, b=1, l=1, d=1)

omega_arr = np.random.random([1000,4])*2
#omega_arr[:,0] = 2
#omega_arr[:,3] = 2
res = simulation(omega_arr)

# %%
omega_arr
# Out:
# array([[0.69118455, 0.62662376, 0.28402263, 1.51087886],
#        [0.88645302, 1.55984204, 0.68170986, 1.39377845],
#        [0.83283913, 1.30660947, 0.70669969, 0.65092927],
#        ...,
#        [0.06603076, 0.66134846, 0.68908109, 1.13200581],
#        [1.68879992, 1.08269393, 1.23740863, 0.87181627],
#        [0.32458231, 1.80883703, 0.95343797, 1.60400741]])

# %%
def plot_pretty(res):
    fig, axs = plt.subplots(nrows=6, ncols=3, figsize=(9,22))
    i=0
    for prefix in ['','v_','a_']:
        for target in ['xyz','rpy']:
            key = '{}{}_arr'.format(prefix, target)
            arr = res[key]
            for j in range(3):
                axs[i,j].plot(arr[:,j])
                axs[i,j].set_title('{}{}-{}'.format(prefix, target, target[j]))
            i+=1
        
    #plt.show()

# %%
xyz = np.array([0.0, 0.0, 0.0])
rpy = np.array([0.0, 0.0, 0.0])
drone = Drone(xyz, rpy, v_xyz=(0,0,0), v_rpy=(0,0,0), 
                 I=(1,1,1), m=1, b=1, l=1, d=1)

omega_arr = np.ones([1000, 4]) * 2
res = simulation(omega_arr, show=[])

# %%
plot_pretty(res)

# %%
xyz = np.array([0.0, 0.0, 0.0])
rpy = np.array([0.0, 0.0, 0.0])
drone = Drone(xyz, rpy, v_xyz=(0,0,0), v_rpy=(0,0,0), 
                 I=(1,1,1), m=1, b=1, l=1, d=1)

omega_arr = np.ones([100, 4])
omega_arr[:5,1] = 2
omega_arr[:5,2] = 2
omega_arr[5:20,1] = 0
omega_arr[5:20,2] = 0
omega_arr
res = simulation(omega_arr, show=[])

# %%
plot_pretty(res)

# %%
xyz = np.array([0.0, 0.0, 0.0])
rpy = np.array([0.0, 0.0, 0.0])
drone = Drone(xyz, rpy, v_xyz=(0,0,0), v_rpy=(0,0,0), 
                 I=(1,1,1), m=1, b=1, l=1, d=1)

omega_arr = np.ones([100, 4]) *2
omega_arr[:5,1] = 3
omega_arr[:5,2] = 3
omega_arr[5:13,1] = 1
omega_arr[5:13,2] = 1
omega_arr
res = simulation(omega_arr, show=[])

# %%
plot_pretty(res)
